# %% [markdown]
# # From Scratch

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf

from tensorflow.keras.preprocessing import image_dataset_from_directory

# %%
PATH = 'rebalanced_cats_and_dogs_2/'
train_dir = os.path.join(PATH, 'train')
validation_dir = os.path.join(PATH, 'validation')

BATCH_SIZE = 128
IMG_SIZE = (160, 160)
BUFFER_SIZE = BATCH_SIZE*5

train_dataset = image_dataset_from_directory(train_dir,
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE)
# Out:
# Found 1000 files belonging to 2 classes.

# %%
validation_dataset = image_dataset_from_directory(validation_dir,
                                                  shuffle=True,
                                                  batch_size=BATCH_SIZE,
                                                  image_size=IMG_SIZE)
# Out:
# Found 3000 files belonging to 2 classes.

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    print(labels[i])
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)

# %%
train_dataset = train_dataset.prefetch(buffer_size=BUFFER_SIZE)
validation_dataset = validation_dataset.prefetch(buffer_size=BUFFER_SIZE)

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
for image, _ in train_dataset.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')

# %%
preprocess_input = tf.keras.applications.vgg16.preprocess_input
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)

# %%
print(IMG_SIZE)
IMG_SHAPE = IMG_SIZE + (3,)
print(IMG_SHAPE)
# Out:
# (160, 160)
# (160, 160, 3)

# %%
# Create the base model from the pre-trained model MobileNet V2
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.VGG16(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights=None)

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# 2022-03-21 19:00:32.370748: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8201
# 2022-03-21 19:00:33.549796: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.58GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-03-21 19:00:33.738435: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-03-21 19:00:33.738477: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-03-21 19:00:34.066034: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-03-21 19:00:34.066086: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# (128, 5, 5, 512)

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (128, 512)

# %%
prediction_layer = tf.keras.layers.Dense(1)
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (128, 1)

# %%
inputs = tf.keras.Input(shape=(160, 160, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x)
x = global_average_layer(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %%
base_learning_rate = 0.0001
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer = tf.keras.optimizers.Adam(base_learning_rate),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  sequential (Sequential)     (None, 160, 160, 3)       0
#
#  tf.__operators__.getitem (S  (None, 160, 160, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 160, 160, 3)      0
#
#  vgg16 (Functional)          (None, 5, 5, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1)                 513
#
# =================================================================
# Total params: 14,715,201
# Trainable params: 14,715,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 28

# %%
history_fine = model.fit(train_dataset,
                         epochs=50,
                         validation_data=validation_dataset)
# Out:
# Epoch 1/50
# 2022-03-21 19:00:47.171783: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-03-21 19:00:47.171831: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-03-21 19:00:47.780060: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-03-21 19:00:47.780109: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.53GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-03-21 19:00:49.088580: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-03-21 19:00:50.738996: I tensorflow/stream_executor/cuda/cuda_blas.cc:1774] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 8/8 [==============================] - 20s 2s/step - loss: 0.7488 - accuracy: 0.5180 - val_loss: 0.6933 - val_accuracy: 0.5000
# Epoch 2/50
# 8/8 [==============================] - 5s 644ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6902 - val_accuracy: 0.5000
# Epoch 3/50
# 8/8 [==============================] - 5s 645ms/step - loss: 0.6863 - accuracy: 0.5000 - val_loss: 0.7001 - val_accuracy: 0.5963
# Epoch 4/50
# 8/8 [==============================] - 5s 644ms/step - loss: 0.6763 - accuracy: 0.5030 - val_loss: 0.6982 - val_accuracy: 0.6250
# Epoch 5/50
# 8/8 [==============================] - 5s 645ms/step - loss: 0.6775 - accuracy: 0.5400 - val_loss: 0.6702 - val_accuracy: 0.5863
# Epoch 6/50
# 8/8 [==============================] - 5s 645ms/step - loss: 0.6487 - accuracy: 0.6070 - val_loss: 0.6700 - val_accuracy: 0.5983
# Epoch 7/50
# 8/8 [==============================] - 5s 646ms/step - loss: 0.6429 - accuracy: 0.6010 - val_loss: 0.6569 - val_accuracy: 0.5730
# Epoch 8/50
# 8/8 [==============================] - 5s 646ms/step - loss: 0.6317 - accuracy: 0.6190 - val_loss: 0.6466 - val_accuracy: 0.5790
# Epoch 9/50
# 8/8 [==============================] - 5s 647ms/step - loss: 0.6335 - accuracy: 0.6180 - val_loss: 0.7191 - val_accuracy: 0.6160
# Epoch 10/50
# 8/8 [==============================] - 5s 650ms/step - loss: 0.6367 - accuracy: 0.5760 - val_loss: 0.6600 - val_accuracy: 0.5940
# Epoch 11/50
# 8/8 [==============================] - 5s 646ms/step - loss: 0.6340 - accuracy: 0.5990 - val_loss: 0.6452 - val_accuracy: 0.6007
# Epoch 12/50
# 8/8 [==============================] - 5s 647ms/step - loss: 0.6174 - accuracy: 0.6490 - val_loss: 0.6949 - val_accuracy: 0.5743
# Epoch 13/50
# 8/8 [==============================] - 5s 647ms/step - loss: 0.6409 - accuracy: 0.6290 - val_loss: 0.6544 - val_accuracy: 0.5493
# Epoch 14/50
# 8/8 [==============================] - 5s 646ms/step - loss: 0.6333 - accuracy: 0.5760 - val_loss: 0.6643 - val_accuracy: 0.6347
# Epoch 15/50
# 8/8 [==============================] - 5s 647ms/step - loss: 0.6125 - accuracy: 0.6520 - val_loss: 0.6447 - val_accuracy: 0.6233
# Epoch 16/50
# 8/8 [==============================] - 5s 647ms/step - loss: 0.6162 - accuracy: 0.6250 - val_loss: 0.6620 - val_accuracy: 0.6440
# Epoch 17/50
# 8/8 [==============================] - 5s 646ms/step - loss: 0.5998 - accuracy: 0.6710 - val_loss: 0.6379 - val_accuracy: 0.6310
# Epoch 18/50
# 8/8 [==============================] - 5s 647ms/step - loss: 0.5915 - accuracy: 0.6680 - val_loss: 0.6295 - val_accuracy: 0.6487
# Epoch 19/50
# 8/8 [==============================] - 5s 648ms/step - loss: 0.5825 - accuracy: 0.6810 - val_loss: 0.6157 - val_accuracy: 0.6353
# Epoch 20/50
# 8/8 [==============================] - 5s 646ms/step - loss: 0.6244 - accuracy: 0.6310 - val_loss: 0.6285 - val_accuracy: 0.6417
# Epoch 21/50
# 8/8 [==============================] - 5s 647ms/step - loss: 0.5916 - accuracy: 0.6670 - val_loss: 0.6212 - val_accuracy: 0.6637
# Epoch 22/50
# 8/8 [==============================] - 5s 647ms/step - loss: 0.5830 - accuracy: 0.6960 - val_loss: 0.6256 - val_accuracy: 0.6543
# Epoch 23/50
# 8/8 [==============================] - 5s 647ms/step - loss: 0.5738 - accuracy: 0.6960 - val_loss: 0.6354 - val_accuracy: 0.6597
# Epoch 24/50
# 8/8 [==============================] - 5s 646ms/step - loss: 0.5699 - accuracy: 0.6830 - val_loss: 0.6283 - val_accuracy: 0.6677
# Epoch 25/50
# 8/8 [==============================] - 5s 647ms/step - loss: 0.5621 - accuracy: 0.7020 - val_loss: 0.6075 - val_accuracy: 0.6517
# Epoch 26/50
# 8/8 [==============================] - 5s 647ms/step - loss: 0.5668 - accuracy: 0.6870 - val_loss: 0.6447 - val_accuracy: 0.6747
# Epoch 27/50
# 8/8 [==============================] - 5s 648ms/step - loss: 0.5983 - accuracy: 0.6770 - val_loss: 0.6170 - val_accuracy: 0.6787
# Epoch 28/50
# 8/8 [==============================] - 5s 648ms/step - loss: 0.5799 - accuracy: 0.6570 - val_loss: 0.6448 - val_accuracy: 0.6603
# Epoch 29/50
# 8/8 [==============================] - 5s 647ms/step - loss: 0.5542 - accuracy: 0.7100 - val_loss: 0.6521 - val_accuracy: 0.6210
# Epoch 30/50
# 8/8 [==============================] - 5s 647ms/step - loss: 0.5463 - accuracy: 0.7130 - val_loss: 0.6044 - val_accuracy: 0.6533
# Epoch 31/50
# 8/8 [==============================] - 5s 648ms/step - loss: 0.5378 - accuracy: 0.7320 - val_loss: 0.6190 - val_accuracy: 0.6473
# Epoch 32/50
# 8/8 [==============================] - 5s 648ms/step - loss: 0.5274 - accuracy: 0.7320 - val_loss: 0.6099 - val_accuracy: 0.6693
# Epoch 33/50
# 8/8 [==============================] - 5s 647ms/step - loss: 0.5305 - accuracy: 0.7240 - val_loss: 0.6631 - val_accuracy: 0.7020
# Epoch 34/50
# 8/8 [==============================] - 5s 652ms/step - loss: 0.5189 - accuracy: 0.7260 - val_loss: 0.6052 - val_accuracy: 0.6590
# Epoch 35/50
# 8/8 [==============================] - 5s 648ms/step - loss: 0.5212 - accuracy: 0.7400 - val_loss: 0.5908 - val_accuracy: 0.6817
# Epoch 36/50
# 8/8 [==============================] - 5s 648ms/step - loss: 0.5187 - accuracy: 0.7260 - val_loss: 0.6042 - val_accuracy: 0.6347
# Epoch 37/50
# 8/8 [==============================] - 5s 648ms/step - loss: 0.4891 - accuracy: 0.7540 - val_loss: 0.6841 - val_accuracy: 0.6450
# Epoch 38/50
# 8/8 [==============================] - 5s 648ms/step - loss: 0.5611 - accuracy: 0.7090 - val_loss: 0.7012 - val_accuracy: 0.6833
# Epoch 39/50
# 8/8 [==============================] - 5s 647ms/step - loss: 0.5463 - accuracy: 0.7090 - val_loss: 0.6059 - val_accuracy: 0.6583
# Epoch 40/50
# 8/8 [==============================] - 5s 648ms/step - loss: 0.5083 - accuracy: 0.7570 - val_loss: 0.6644 - val_accuracy: 0.7157
# Epoch 41/50
# 8/8 [==============================] - 5s 648ms/step - loss: 0.5122 - accuracy: 0.7500 - val_loss: 0.5860 - val_accuracy: 0.6793
# Epoch 42/50
# 8/8 [==============================] - 5s 647ms/step - loss: 0.4944 - accuracy: 0.7410 - val_loss: 0.5792 - val_accuracy: 0.6907
# Epoch 43/50
# 8/8 [==============================] - 5s 647ms/step - loss: 0.4797 - accuracy: 0.7740 - val_loss: 0.6284 - val_accuracy: 0.7280
# Epoch 44/50
# 8/8 [==============================] - 5s 648ms/step - loss: 0.4873 - accuracy: 0.7520 - val_loss: 0.5823 - val_accuracy: 0.6793
# Epoch 45/50
# 8/8 [==============================] - 5s 648ms/step - loss: 0.4768 - accuracy: 0.7660 - val_loss: 0.5887 - val_accuracy: 0.6807
# Epoch 46/50
# 8/8 [==============================] - 5s 648ms/step - loss: 0.4860 - accuracy: 0.7560 - val_loss: 0.5675 - val_accuracy: 0.6917
# Epoch 47/50
# 8/8 [==============================] - 5s 647ms/step - loss: 0.4696 - accuracy: 0.7680 - val_loss: 0.6173 - val_accuracy: 0.7333
# Epoch 48/50
# 8/8 [==============================] - 5s 648ms/step - loss: 0.4641 - accuracy: 0.7780 - val_loss: 0.6318 - val_accuracy: 0.6630
# Epoch 49/50
# 8/8 [==============================] - 5s 648ms/step - loss: 0.4648 - accuracy: 0.7740 - val_loss: 0.5981 - val_accuracy: 0.7240
# Epoch 50/50
# 8/8 [==============================] - 5s 648ms/step - loss: 0.4443 - accuracy: 0.7920 - val_loss: 0.6162 - val_accuracy: 0.6897

# %%
acc = history_fine.history['accuracy']
val_acc = history_fine.history['val_accuracy']

loss = history_fine.history['loss']
val_loss = history_fine.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
total_correct_cats = 0
total_correct_dogs = 0
total_correct = 0

for x,y in validation_dataset:    
    output = model.predict(x)
    
    prediction = output > 0.5   
    prediction = tf.dtypes.cast(prediction, tf.int32)
        
    correct_pre = prediction[:,0] == y
    correct_pre = tf.dtypes.cast(correct_pre, tf.int32)
    
    # accumulate
    total_correct = total_correct + tf.math.reduce_sum(correct_pre)
    total_correct_cats = total_correct_cats + tf.math.reduce_sum(correct_pre[y==0])
    total_correct_dogs = total_correct_dogs + tf.math.reduce_sum(correct_pre[y==1])
        
print('total_correct: ', total_correct)
print('total_correct_cats: ', total_correct_cats)
print('total_correct_dogs: ', total_correct_dogs)
# Out:
# total_correct:  tf.Tensor(2069, shape=(), dtype=int32)
# total_correct_cats:  tf.Tensor(1335, shape=(), dtype=int32)
# total_correct_dogs:  tf.Tensor(734, shape=(), dtype=int32)
