# %% [markdown]
# # From Scratch

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf

from tensorflow.keras.preprocessing import image_dataset_from_directory

# %%
PATH = 'rebalanced_cats_and_dogs_over/'
train_dir = os.path.join(PATH, 'train')
validation_dir = os.path.join(PATH, 'validation')

BATCH_SIZE = 128
IMG_SIZE = (160, 160)
BUFFER_SIZE = BATCH_SIZE*5

train_dataset = image_dataset_from_directory(train_dir,
                                             shuffle=True,
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE)
# Out:
# Found 22000 files belonging to 2 classes.
# 2022-03-22 13:42:44.725700: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 13:42:44.730069: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 13:42:44.730746: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 13:42:44.731699: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-22 13:42:44.732072: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 13:42:44.732745: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 13:42:44.733389: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 13:42:45.009961: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 13:42:45.010644: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 13:42:45.011298: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-22 13:42:45.011956: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21565 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
validation_dataset = image_dataset_from_directory(validation_dir,
                                                  shuffle=True,
                                                  batch_size=BATCH_SIZE,
                                                  image_size=IMG_SIZE)
# Out:
# Found 3000 files belonging to 2 classes.

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
  for i in range(9):
    print(labels[i])
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(0, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(1, shape=(), dtype=int32)

# %%
train_dataset = train_dataset.prefetch(buffer_size=BUFFER_SIZE)
validation_dataset = validation_dataset.prefetch(buffer_size=BUFFER_SIZE)

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
for image, _ in train_dataset.take(1):
  plt.figure(figsize=(10, 10))
  first_image = image[0]
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
    plt.imshow(augmented_image[0] / 255)
    plt.axis('off')

# %%
preprocess_input = tf.keras.applications.vgg16.preprocess_input
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset= -1)

# %%
print(IMG_SIZE)
IMG_SHAPE = IMG_SIZE + (3,)
print(IMG_SHAPE)
# Out:
# (160, 160)
# (160, 160, 3)

# %%
# Create the base model from the pre-trained model MobileNet V2
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.VGG16(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights=None)

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# 2022-03-22 13:42:46.667044: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8100
# (128, 5, 5, 512)

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (128, 512)

# %%
prediction_layer = tf.keras.layers.Dense(1)
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (128, 1)

# %%
inputs = tf.keras.Input(shape=(160, 160, 3))
x = data_augmentation(inputs)
x = preprocess_input(x)
x = base_model(x)
x = global_average_layer(x)
outputs = prediction_layer(x)
model = tf.keras.Model(inputs, outputs)

# %%
base_learning_rate = 0.0001
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer = tf.keras.optimizers.Adam(base_learning_rate),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  sequential (Sequential)     (None, 160, 160, 3)       0
#
#  tf.__operators__.getitem (S  (None, 160, 160, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 160, 160, 3)      0
#
#  vgg16 (Functional)          (None, 5, 5, 512)         14714688
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1)                 513
#
# =================================================================
# Total params: 14,715,201
# Trainable params: 14,715,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 28

# %%
history_fine = model.fit(train_dataset,
                         epochs=25,
                         validation_data=validation_dataset)
# Out:
# Epoch 1/25
# 2022-03-22 13:42:49.213004: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 172/172 [==============================] - 46s 251ms/step - loss: 0.6562 - accuracy: 0.5392 - val_loss: 0.7135 - val_accuracy: 0.5797
# Epoch 2/25
# 172/172 [==============================] - 39s 229ms/step - loss: 0.5746 - accuracy: 0.6711 - val_loss: 0.6386 - val_accuracy: 0.6920
# Epoch 3/25
# 172/172 [==============================] - 40s 229ms/step - loss: 0.5174 - accuracy: 0.7231 - val_loss: 0.5969 - val_accuracy: 0.7203
# Epoch 4/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.4558 - accuracy: 0.7718 - val_loss: 0.5934 - val_accuracy: 0.7270
# Epoch 5/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.4017 - accuracy: 0.8093 - val_loss: 0.5083 - val_accuracy: 0.7593
# Epoch 6/25
# 172/172 [==============================] - 40s 231ms/step - loss: 0.3722 - accuracy: 0.8260 - val_loss: 0.5262 - val_accuracy: 0.7773
# Epoch 7/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.3260 - accuracy: 0.8531 - val_loss: 0.4191 - val_accuracy: 0.8137
# Epoch 8/25
# 172/172 [==============================] - 40s 231ms/step - loss: 0.3043 - accuracy: 0.8641 - val_loss: 0.7581 - val_accuracy: 0.7170
# Epoch 9/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.2772 - accuracy: 0.8765 - val_loss: 0.4646 - val_accuracy: 0.8280
# Epoch 10/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.2544 - accuracy: 0.8891 - val_loss: 0.4493 - val_accuracy: 0.8387
# Epoch 11/25
# 172/172 [==============================] - 40s 231ms/step - loss: 0.2315 - accuracy: 0.8993 - val_loss: 0.7498 - val_accuracy: 0.7357
# Epoch 12/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.2187 - accuracy: 0.9084 - val_loss: 0.3871 - val_accuracy: 0.8430
# Epoch 13/25
# 172/172 [==============================] - 40s 231ms/step - loss: 0.2103 - accuracy: 0.9102 - val_loss: 0.4025 - val_accuracy: 0.8500
# Epoch 14/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.2029 - accuracy: 0.9155 - val_loss: 0.5672 - val_accuracy: 0.8177
# Epoch 15/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.1857 - accuracy: 0.9230 - val_loss: 0.3487 - val_accuracy: 0.8597
# Epoch 16/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.1786 - accuracy: 0.9249 - val_loss: 0.3596 - val_accuracy: 0.8600
# Epoch 17/25
# 172/172 [==============================] - 40s 231ms/step - loss: 0.1658 - accuracy: 0.9322 - val_loss: 0.4796 - val_accuracy: 0.8607
# Epoch 18/25
# 172/172 [==============================] - 40s 232ms/step - loss: 0.1600 - accuracy: 0.9334 - val_loss: 0.3900 - val_accuracy: 0.8730
# Epoch 19/25
# 172/172 [==============================] - 40s 231ms/step - loss: 0.1526 - accuracy: 0.9369 - val_loss: 0.3626 - val_accuracy: 0.8863
# Epoch 20/25
# 172/172 [==============================] - 40s 231ms/step - loss: 0.1393 - accuracy: 0.9447 - val_loss: 0.4636 - val_accuracy: 0.8623
# Epoch 21/25
# 172/172 [==============================] - 40s 231ms/step - loss: 0.1350 - accuracy: 0.9463 - val_loss: 0.5403 - val_accuracy: 0.8347
# Epoch 22/25
# 172/172 [==============================] - 40s 231ms/step - loss: 0.1233 - accuracy: 0.9500 - val_loss: 0.5167 - val_accuracy: 0.8553
# Epoch 23/25
# 172/172 [==============================] - 40s 230ms/step - loss: 0.1237 - accuracy: 0.9505 - val_loss: 0.4346 - val_accuracy: 0.8750
# Epoch 24/25
# 172/172 [==============================] - 40s 231ms/step - loss: 0.1223 - accuracy: 0.9508 - val_loss: 0.3447 - val_accuracy: 0.8953
# Epoch 25/25
# 172/172 [==============================] - 40s 231ms/step - loss: 0.1152 - accuracy: 0.9554 - val_loss: 0.5187 - val_accuracy: 0.8683

# %%
acc = history_fine.history['accuracy']
val_acc = history_fine.history['val_accuracy']

loss = history_fine.history['loss']
val_loss = history_fine.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
total_correct_cats = 0
total_correct_dogs = 0
total_correct = 0

for x,y in validation_dataset:    
    output = model.predict(x)
    
    prediction = output > 0.5   
    prediction = tf.dtypes.cast(prediction, tf.int32)
        
    correct_pre = prediction[:,0] == y
    correct_pre = tf.dtypes.cast(correct_pre, tf.int32)
    
    # accumulate
    total_correct = total_correct + tf.math.reduce_sum(correct_pre)
    total_correct_cats = total_correct_cats + tf.math.reduce_sum(correct_pre[y==0])
    total_correct_dogs = total_correct_dogs + tf.math.reduce_sum(correct_pre[y==1])
        
print('total_correct: ', total_correct)
print('total_correct_cats: ', total_correct_cats)
print('total_correct_dogs: ', total_correct_dogs)
# Out:
# total_correct:  tf.Tensor(2605, shape=(), dtype=int32)
# total_correct_cats:  tf.Tensor(1167, shape=(), dtype=int32)
# total_correct_dogs:  tf.Tensor(1438, shape=(), dtype=int32)
